# %%
# %matplotlib inline

# %% [markdown]
# # Guardar y cargar el modelo

# %% [markdown]
# Puede que queramos guardar el modelo una vez entrenado para luego poder utilizarlo en producción, de modo que vamos a ver varias formas de hacerlo
